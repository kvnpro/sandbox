# %% [markdown]
# ### Face detection using OPENCV
#
# [OpenCV for Face Detection Tutorial](https://www.datacamp.com/tutorial/face-detection-python-opencv)

# %%
import cv2

# %%
imagePath = "/Users/kevin/Desktop/Crown73/Scan 25.png"
img = cv2.imread(imagePath)

# %%
img.shape
# Out:
# (3300, 2548, 3)

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_image.shape
# Out:
# (3300, 2548)

# %%
face_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
face =face_classifier.detectMultiScale(gray_image, scaleFactor=1.1,minNeighbors=5,minSize=(200,200))

# %%
for (x,y,w,h) in face:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0),4)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
#%pip install matplotlib
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 2547.5, 3299.5, -0.5)
